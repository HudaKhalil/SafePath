# %% [markdown]
# ### 1) Inspect one DataFrame (cleaned or raw)

# %%
import pandas as pd

# Point to a file (cleaned or a raw CSV)
path = "london_crime_clean.csv"   # or r"C:\...\2025-08\2025-08-metropolitan-street.csv"

# Load a small sample to avoid heavy memory use
df = pd.read_csv(path, nrows=10_000)

# Basic structure
print("Shape (rows, cols):", df.shape)
print("\nColumn names:", list(df.columns))

print("\nDtypes:")
print(df.dtypes)

print("\nMemory (MB):", df.memory_usage(deep=True).sum()/1e6)

print("\n.info():")
df.info()

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Shape (rows, cols): (10000, 17)
#
# Column names: ['crime_id', 'month', 'reported_by', 'falls_within', 'longitude', 'latitude', 'location', 'lsoa_code', 'lsoa_name', 'crime_type', 'last_outcome_category', 'context', 'month_dt', 'crime_category', 'severity_weight', 'season', 'temporal_weight']
#
# Dtypes:
# crime_id                  object
# month                     object
# reported_by               object
# falls_within              object
# longitude                float64
# latitude                 float64
# location                  object
# lsoa_code                 object
# lsoa_name                 object
# crime_type                object
# last_outcome_category     object
# context                  float64
# month_dt                  object
# crime_category            object
# severity_weight          float64
# season                    object
# temporal_weight          float64
# dtype: object
#
# Memory (MB): 8.611929
#
# .info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   crime_id               8496 non-null   object
#  1   month                  10000 non-null  object
#  2   reported_by            10000 non-null  object
#  3   falls_within           10000 non-null  object
#  4   longitude              10000 non-null  float64
#  5   latitude               10000 non-null  float64
#  6   location               10000 non-null  object
#  7   lsoa_code              10000 non-null  object
#  8   lsoa_name              10000 non-null  object
#  9   crime_type             10000 non-null  object
#  10  last_outcome_category  10000 non-null  object
#  11  context                0 non-null      float64
#  12  month_dt               10000 non-null  object
#  13  crime_category         10000 non-null  object
#  14  severity_weight        10000 non-null  float64
#  15  season                 10000 non-null  object
#  16  temporal_weight        10000 non-null  float64
# dtypes: float64(5), object(12)
# memory usage: 1.3+ MB
#
# First 5 rows:
#                                             crime_id    month  \
# 0  6d7f30fffe77c6d35ec8d6f3b2d1ca8ae1930953054acb...  2025-08
# 1  a0ffce437b5fd8b6fbc7a61ba29754fee8d95b2c0f1001...  2025-08
# 2                                                NaN  2025-08
# 3                                                NaN  2025-08
# 4                                                NaN  2025-08
#
#                    reported_by                 falls_within  longitude  \
# 0  Metropolitan Police Service  Metropolitan Police Service  -0.508514
# 1  Metropolitan Police Service  Metropolitan Police Service   0.893999
# 2  Metropolitan Police Service  Metropolitan Police Service   0.136513
# 3  Metropolitan Police Service  Metropolitan Police Service   0.142112
# 4  Metropolitan Police Service  Metropolitan Police Service   0.140194
#
#     latitude                    location  lsoa_code  \
# 0  50.812629  On or near Wakehurst Place  E01031464
# 1  51.147132   On or near Foxglove Green  E01024003
# 2  51.588214   On or near Kingston Close  E01000027
# 3  51.589389            On or near A1112  E01000027
# 4  51.582356      On or near Hatch Grove  E01000027
#
#                    lsoa_name                    crime_type  \
# 0                  Arun 007F  Violence and sexual offences
# 1               Ashford 006D  Violence and sexual offences
# 2  Barking and Dagenham 001A         Anti-social behaviour
# 3  Barking and Dagenham 001A         Anti-social behaviour
# 4  Barking and Dagenham 001A         Anti-social behaviour
#
#   last_outcome_category  context    month_dt       crime_category  \
# 0   Under investigation      NaN  2025-08-01      Violence_Sexual
# 1   Under investigation      NaN  2025-08-01      Violence_Sexual
# 2       Outcome Pending      NaN  2025-08-01  Antisocial_Behavior
# 3       Outcome Pending      NaN  2025-08-01  Antisocial_Behavior
# 4       Outcome Pending      NaN  2025-08-01  Antisocial_Behavior
#
#    severity_weight  season  temporal_weight
# 0              3.0  Summer         0.737703
# 1              3.0  Summer         0.737703
# 2              1.0  Summer         0.737703
# 3              1.0  Summer         0.737703
# 4              1.0  Summer         0.737703

# %% [markdown]
# ### 2) Quick data-quality snapshot (dtype, % missing, examples)

# %%
import numpy as np

def schema_summary(df, n_example=1):
    out = []
    for c in df.columns:
        s = df[c]
        miss_pct = s.isna().mean()*100
        dtype = s.dtype
        nunique = s.nunique(dropna=True)
        example = s.dropna().iloc[:n_example].tolist()
        out.append({
            "column": c,
            "dtype": str(dtype),
            "nunique": int(nunique),
            "%missing": round(miss_pct, 2),
            "example": example[0] if example else None
        })
    return pd.DataFrame(out).sort_values("%missing", ascending=False)

schema_summary(df)
# Out:
#                    column    dtype  nunique  %missing  \
# 11                context  float64        0    100.00
# 0                crime_id   object     8491     15.04
# 9              crime_type   object       14      0.00
# 15                 season   object        1      0.00
# 14        severity_weight  float64       11      0.00
# 13         crime_category   object       14      0.00
# 12               month_dt   object        1      0.00
# 10  last_outcome_category   object       12      0.00
# 8               lsoa_name   object      753      0.00
# 1                   month   object        1      0.00
# 7               lsoa_code   object      753      0.00
# 6                location   object     3424      0.00
# 5                latitude  float64     4190      0.00
# 4               longitude  float64     4213      0.00
# 3            falls_within   object        1      0.00
# 2             reported_by   object        1      0.00
# 16        temporal_weight  float64        1      0.00
#
#                                               example
# 11                                               None
# 0   6d7f30fffe77c6d35ec8d6f3b2d1ca8ae1930953054acb...
# 9                        Violence and sexual offences
# 15                                             Summer
# 14                                                3.0
# 13                                    Violence_Sexual
# 12                                         2025-08-01
# 10                                Under investigation
# 8                                           Arun 007F
# 1                                             2025-08
# 7                                           E01031464
# 6                          On or near Wakehurst Place
# 5                                           50.812629
# 4                                           -0.508514
# 3                         Metropolitan Police Service
# 2                         Metropolitan Police Service
# 16                                           0.737703

# %% [markdown]
# ### 3) Peek categorical values (e.g., crime types)

# %%
# Top categories
if "crime_type" in df.columns:
    display(df["crime_type"].value_counts().head(20))

# After cleaning, you may have 'crime_category'
if "crime_category" in df.columns:
    display(df["crime_category"].value_counts().head(20))
# Out:
# crime_type
# Violence and sexual offences    2947
# Anti-social behaviour           1504
# Vehicle crime                    896
# Shoplifting                      851
# Other theft                      694
# Drugs                            677
# Criminal damage and arson        620
# Public order                     534
# Burglary                         446
# Theft from the person            326
# Robbery                          254
# Other crime                      127
# Bicycle theft                     66
# Possession of weapons             58
# Name: count, dtype: int64
# crime_category
# Violence_Sexual        2947
# Antisocial_Behavior    1504
# Vehicle_Crime           896
# Theft_Retail            851
# Theft_Other             694
# Drug_Offenses           677
# Criminal_Damage         620
# Public_Order            534
# Burglary                446
# Theft_Personal          326
# Robbery                 254
# Other                   127
# Theft_Bicycle            66
# Weapons                  58
# Name: count, dtype: int64

# %% [markdown]
# ### 4) Check missing values per column (fast)

# %%
df.isna().mean().sort_values(ascending=False).mul(100).round(2).rename("% missing")
# Out:
# context                  100.00
# crime_id                  15.04
# crime_type                 0.00
# season                     0.00
# severity_weight            0.00
# crime_category             0.00
# month_dt                   0.00
# last_outcome_category      0.00
# lsoa_name                  0.00
# month                      0.00
# lsoa_code                  0.00
# location                   0.00
# latitude                   0.00
# longitude                  0.00
# falls_within               0.00
# reported_by                0.00
# temporal_weight            0.00
# Name: % missing, dtype: float64

# %% [markdown]
# ### 5) Inspect multiple raw CSVs in your folder (columns + shapes)

# %%
import glob, os

BASE_DIR = r"C:\Users\hksai\OneDrive\Documents\Group_Porject_Doc\Data_Police_UK_ALL(2025)\2025-08"
files = sorted(glob.glob(os.path.join(BASE_DIR, "*.csv")))
print("Found CSVs:", len(files))
for f in files[:5]:  # show first few
    df0 = pd.read_csv(f, nrows=5000)   # sample
    print("\nFile:", os.path.basename(f))
    print("  shape(sample):", df0.shape)
    print("  columns:", list(df0.columns))

# Union of all columns across files (sampled)
all_cols = set()
for f in files[:10]:
    all_cols |= set(pd.read_csv(f, nrows=1000).columns)
print("\nUnion of columns across sampled files:", all_cols)
# Out:
# Found CSVs: 41
#
# File: 2025-08-avon-and-somerset-street.csv
#   shape(sample): (5000, 12)
#   columns: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
#
# File: 2025-08-bedfordshire-street.csv
#   shape(sample): (5000, 12)
#   columns: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
#
# File: 2025-08-cambridgeshire-street.csv
#   shape(sample): (5000, 12)
#   columns: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
#
# File: 2025-08-cheshire-street.csv
#   shape(sample): (5000, 12)
#   columns: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
#
# File: 2025-08-cleveland-street.csv
#   shape(sample): (5000, 12)
#   columns: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
#
# Union of columns across sampled files: {'Context', 'LSOA code', 'Latitude', 'Falls within', 'Location', 'Month', 'Last outcome category', 'Crime ID', 'LSOA name', 'Crime type', 'Longitude', 'Reported by'}

# %% [markdown]
# ### 6) Numeric summary (quick stats)

# %%
df.describe().T  # numeric columns
# Out:
#                    count       mean           std        min        25%  \
# longitude        10000.0  -0.105113  2.166376e-01  -3.237972  -0.249853
# latitude         10000.0  51.545623  8.313141e-02  50.717819  51.531224
# context              0.0        NaN           NaN        NaN        NaN
# severity_weight  10000.0   1.866020  8.687755e-01   0.800000   1.000000
# temporal_weight  10000.0   0.737703  4.441114e-14   0.737703   0.737703
#
#                        50%        75%        max
# longitude        -0.195865   0.110713   0.893999
# latitude         51.551073  51.581820  53.820109
# context                NaN        NaN        NaN
# severity_weight   1.500000   3.000000   3.000000
# temporal_weight   0.737703   0.737703   0.737703

# %% [markdown]
# ### 7) Save the schema to a CSV (handy for docs)

# %%
schema_summary(df).to_csv("schema_summary.csv", index=False)
print("Saved -> schema_summary.csv")
# Out:
# Saved -> schema_summary.csv

# %% [markdown]
# ##### These all commands will show shapes, column names, data types, missingness, example values, and category distributions—everything to understand the structure quickly.
